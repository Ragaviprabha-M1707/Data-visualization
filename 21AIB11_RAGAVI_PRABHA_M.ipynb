# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_csv("winequalityN.csv")
df=df.head(250)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  250 non-null    object
#  1   fixed acidity         247 non-null    float64
#  2   volatile acidity      249 non-null    float64
#  3   citric acid           250 non-null    float64
#  4   residual sugar        249 non-null    float64
#  5   chlorides             249 non-null    float64
#  6   free sulfur dioxide   250 non-null    float64
#  7   total sulfur dioxide  250 non-null    float64
#  8   density               250 non-null    float64
#  9   pH                    248 non-null    float64
#  10  sulphates             249 non-null    float64
#  11  alcohol               250 non-null    float64
#  12  quality               250 non-null    int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 25.5+ KB

# %%
df.shape
# Out:
# (250, 13)

# %%
df.nunique()
# Out:
# type                      1
# fixed acidity            34
# volatile acidity         53
# citric acid              49
# residual sugar          109
# chlorides                54
# free sulfur dioxide      68
# total sulfur dioxide    131
# density                  78
# pH                       56
# sulphates                45
# alcohol                  40
# quality                   5
# dtype: int64

# %%
plt.bar(df['total sulfur dioxide'],df['fixed acidity'])
# Out:
# <BarContainer object of 250 artists>

# %%
plt.hist(df['citric acid'],color='pink',edgecolor='black')
plt.title('Citric Acid')
# Out:
# Text(0.5, 1.0, 'Citric Acid')

# %%
df.plot.bar()

# %%
plt.scatter(df['chlorides'],df['quality'],color='green')
plt.xlabel('CHLORIDES')
plt.ylabel('QUALITY')
# Out:
# Text(0, 0.5, 'QUALITY')

# %%
plt.plot(df['alcohol'],label='alcohol')
plt.title('ALCOHOL LEVEL')
# Out:
# Text(0.5, 1.0, 'ALCOHOL LEVEL')

# %%
plt.stem(df['volatile acidity'])
plt.title("VOLATILE ACIDITY")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'VOLATILE ACIDITY')

# %%
df.plot.area()
